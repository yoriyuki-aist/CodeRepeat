# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
count_matrix = pd.read_csv('../../code-clone-experiments/fiber-matrix.csv')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.heatmap(count_matrix, xticklabels=False, yticklabels=False)

# %%
count_matrix
# Out:
#     ../code-clone-experiments/fiber-master/app.go  \
# 0                                            1612
# 1                                            5745
# 2                                            2104
# 3                                           13542
# 4                                            1139
# 5                                             907
# 6                                            1739
# 7                                             841
# 8                                            1353
# 9                                             954
# 10                                              0
# 11                                           1284
# 12                                           1363
# 13                                            872
# 14                                            775
# 15                                           1040
# 16                                            918
# 17                                           1928
# ...

# %%
sr = count_matrix.idxmax(axis=1)

# %%
sr[3]
# Out:
# '../code-clone-experiments/fiber-master/ctx_test.go'
